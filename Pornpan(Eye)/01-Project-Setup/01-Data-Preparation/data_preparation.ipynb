# %% [markdown]
# # Data Preparation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# load all 9 `.csv` files each of them as a `pandas.DataFrame` in a single dict named `data` where each key is the name of the csv file, and each value is the dataframe created from the csv
# ```python
# data = {
#     'sellers': DataFrame1,
#     'orders': DataFrame2,
#     ...
#     }
# ```

# %% [markdown]
# ### 1. Create the variable `csv_path`, which stores the path to  `"csv" folder` as a string

# %% [markdown]
# - When calling `pd.read_csv(csv_path)`, `csv_path` can be absolute or relative:
#     - A **`relative path`** can start with `.` or `..`, it is always computed with respect to your current working directory
#         - *Reminder: you can use `!pwd` in your notebook or `pwd` in your terminal to know where you are located*
#     - An **`absolute path`** starts with `/`

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# ☝️ `getcwd` a.k.a `get current working directory` refers to the absolute path _from which this notebook is being executed_
#
# Create a relative `csv_path`.

# %%
csv_path = '../data/csv' 
csv_path = os.path.join('..','/content/drive/MyDrive/Pornpan(Eye)/01-Project-Setup/01-Context-and-Setup/Data') 
csv_path
# Out:
# '/content/drive/MyDrive/Pornpan(Eye)/01-Project-Setup/01-Context-and-Setup/Data'

# %%
import pandas as pd
pd.read_csv(os.path.join(csv_path, '/content/drive/MyDrive/Pornpan(Eye)/01-Project-Setup/01-Context-and-Setup/Data/olist_sellers_dataset.csv')).head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### 2. Create the list `file_names` containing all csv file names in the csv directory
#
# - Make sure it only lists csv files!

# %%
file_names = [f for f in os.listdir(csv_path) if f.endswith('.csv')]
file_names
# Out:
# ['olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_products_dataset.csv',
#  'product_category_name_translation.csv',
#  'olist_sellers_dataset.csv']

# %% [markdown]
# ### 3.  Create the list of dict key `key_names`
# Starting from file_names and:
# - Removing its suffix ".csv" when it exists
# - Removing its suffix "_dataset.csv" when it exists
# - Removing its prefix "olist_" when it exists

# %%
key_names = [key_name
    .replace('olist_','')
    .replace('_dataset','')
    .replace('.csv','')
    for key_name in file_names]
key_names
# Out:
# ['customers',
#  'geolocation',
#  'order_items',
#  'order_payments',
#  'order_reviews',
#  'orders',
#  'products',
#  'product_category_name_translation',
#  'sellers']

# %% [markdown]
# ### 4. Construct the dictionary `data`
#
# ```python
# data = {
#     'sellers': DataFrame1,
#     'orders': DataFrame2,
#     'order_items': DataFrame3,
#     ...
#     }
# ```

# %%
data = {}
for k,f in zip(key_names, file_names):
    data[k] = pd.read_csv(os.path.join(csv_path, f))
data.keys()
# Out:
# dict_keys(['customers', 'geolocation', 'order_items', 'order_payments', 'order_reviews', 'orders', 'products', 'product_category_name_translation', 'sellers'])
