# %% [markdown]
# # Project - Data Science
# ![DS_steps.png](DS_steps.png)

# %% [markdown]
# ## Pornpan Thongdee (Eye):

# %% [markdown]
# ## Project Topic:  CEO-REQUEST

# %% [markdown]
# ---
# ## Current Situation / Problem Statement
#
# How should Olist improve its profit margin❓

# %% [markdown]
# ## Objectives:
# 1. Increase revenues per sellers per months 5%
# 2. Reduce underperforming products/categories from its marketplace?
# 3. Reduce some reputation costs (estimated) per bad reviews

# %% [markdown]
# ## Hypothesis-driven Questions:
#
#
# 1.   Should Olist remove the worst performing products / categories from its marketplace entirely?
# 2.   Should Olist remove only consistently underperforming sellers, after it has a honeymoon period of few months?
# 3. Should Olist acquire new sellers, with some cost assumptions to be suggested?

# %% [markdown]
# ## Dataset:
# Sellers, orders, products
# (Data released on Kaggle in November 2018)

# %% [markdown]
# ## Should Olist remove underperforming products/categories from its marketplace?

# %%
#Coding...
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
csv_path = os.path.join("../../data/csv")
csv_path
# Out:
# '../../data/csv'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Pornpan(Eye)/olist/data.py')
# df = pd.read_csv('../Pornpan/dirtydata.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-90900b98e33d> in <module>
# ----> 1 df = pd.read_csv('../Pornpan(Eye)/olist/data.py')
#       2 # df = pd.read_csv('../Pornpan/dirtydata.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from olist.data import Olist
data = Olist().get_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-0a52b8cf0efe> in <module>
# ----> 1 from olist.data import Olist
#       2 data = Olist().get_data()
#
# ModuleNotFoundError: No module named 'olist'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from olist.product_updated import Product
product = Product()
products = product.get_training_data()
products.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-4da0d2b6abc5> in <module>
# ----> 1 from olist.product_updated import Product
#       2 product = Product()
#       3 products = product.get_training_data()
#       4 products.shape
#
# ModuleNotFoundError: No module named 'olist'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Data Preparation (Data Cleaning):

# %% [markdown]
# Description...
# 1. xxx
# 2. xxx
# 3. xxx

# %% [markdown]
# #### Section 1

# %%
#Coding...

# %% [markdown]
# #### Section 2

# %%
#Coding...

# %% [markdown]
# #### Section 3

# %%
#Coding...

# %% [markdown]
# ## Exploratory Data Analysis (EDA):

# %% [markdown]
# Description...
# 1. xxx
# 2. xxx
# 3. xxx

# %% [markdown]
# #### Section 1

# %%
#Coding...

# %% [markdown]
# #### Section 2

# %%
#Coding...

# %% [markdown]
# #### Section 3

# %%
#Coding...

# %% [markdown]
# ## Key Findings:

# %% [markdown]
# Description...
# 1. xxx
# 2. xxx
# 3. xxx

# %% [markdown]
# <div class="alert alert-info">
# <h3>What’s Next / Recommendation:</h3>
# </div>

# %% [markdown]
# Description...
# 1. xxx
# 2. xxx
# 3. xxx

# %% [markdown]
# <div class="alert alert-info">
# <h3>Financial Benefit:</h3>
# </div>

# %% [markdown]
# Description...
# 1. xxx
# 2. xxx
# 3. xxx

# %% [markdown]
# <div class="alert alert-info">
# <h3>Non-Financial Benefit:</h3>
# </div>

# %% [markdown]
# Description...
# 1. xxx
# 2. xxx
# 3. xxx
